# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import random
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import precision_score,recall_score, f1_score,accuracy_score, confusion_matrix
from sklearn.metrics import roc_auc_score,roc_curve,auc,classification_report

# %%
df_cc=pd.read_csv("../data/creditcard.csv")

# %%
df_cc.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(df_cc['Amount'].min())
print(df_cc['Amount'].max())
print(df_cc['Amount'].mean())
print(df_cc['Amount'].median())
# Out:
# 0.0
# 25691.16
# 88.34961925093133
# 22.0

# %%
df_cc.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df_cc['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df_cc.groupby(['Class'])['Class'].count().plot.bar()
# Out:
# <AxesSubplot: xlabel='Class'>

# %%
dup=df_cc[df_cc.duplicated()]
dup
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
df_cc=df_cc.drop_duplicates()
df_cc
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df_cc['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
df_cc.corr()['Class'].sort_values(ascending=False)
# Out:
# Class     1.000000
# V11       0.149067
# V4        0.129326
# V2        0.084624
# V19       0.033631
# V8        0.033068
# V21       0.026357
# V27       0.021892
# V20       0.021486
# V28       0.009682
# Amount    0.005777
# V22       0.004887
# V26       0.004265
# V25       0.003202
# V15      -0.003300
# V13      -0.003897
# V23      -0.006333
# V24      -0.007210
# Time     -0.012359
# V6       -0.043915
# V5       -0.087812
# V9       -0.094021
# V1       -0.094486
# V18      -0.105340
# V7       -0.172347
# V3       -0.182322
# V16      -0.187186
# V10      -0.206971
# V12      -0.250711
# V14      -0.293375
# V17      -0.313498
# Name: Class, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20,10)) 
heatmap = sns.heatmap(df_cc.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':10}, pad=16)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
fig, ax = plt.subplots(6, 5, figsize=(50, 50))

m=1
for i in range(6):
    for j in range(5):

        df_cc.hist(column = df_cc.columns[m], bins = 40, ax=ax[i,j] )
        m+=1

# %% [markdown]
# Preparing columns for the model

# %%
df_cc['time_scaled']=sc.fit_transform(df_cc[['Time']])
df_cc['amount_scaled']=sc.fit_transform(df_cc[['Amount']])

# %%
X=df_cc.drop(['Time','Amount','Class'],axis=1)
y=df_cc['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=50, stratify=y)

# %% [markdown]
# ##### Basic model with the imbalanced data

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict_lr_imb=lr.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_predict_lr_imb))
print("Precision:",precision_score(y_test, y_predict_lr_imb))
print("Recall:",recall_score(y_test, y_predict_lr_imb))
print("f1:",f1_score(y_test, y_predict_lr_imb))
print("ROC AUC Score:",roc_auc_score(y_test, y_predict_lr_imb))
fpr, tpr, thresholds =roc_curve(y_test, y_predict_lr_imb)
roc_auc = auc(fpr, tpr)
print(fpr)
print(tpr)
print(thresholds)
# Out:
# Accuracy: 0.999177612255927
# Precision: 0.8461538461538461
# Recall: 0.6197183098591549
# f1: 0.7154471544715447
# ROC AUC Score: 0.8097650107006188
# [0.00000000e+00 1.88288458e-04 1.00000000e+00]
# [0.         0.61971831 1.        ]
# [2 1 0]

# %%
cm=confusion_matrix(y_test, y_predict_lr_imb)
sns.heatmap(cm, annot=True,fmt = ".1f",
                    cmap=plt.cm.Reds,
                   xticklabels=['No Fraud', 'Fraud'],
                   yticklabels=['No Fraud', 'Fraud']).set_title('Logistic Regression')
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %%
print(classification_report(y_test, y_predict_lr_imb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84976
#            1       0.85      0.62      0.72       142
#
#     accuracy                           1.00     85118
#    macro avg       0.92      0.81      0.86     85118
# weighted avg       1.00      1.00      1.00     85118

# %%
pickle.dump(lr, open('../models/lr_imb.pkl', 'wb'))

# %% [markdown]
# #### Cost sensitive learning

# %% [markdown]
# ###### 1. undersampling and oversampling the data

# %%
undersample = RandomUnderSampler()
X_under, y_under = undersample.fit_resample(X, y)

# %%
X_train_under, X_test_under, y_train_under, y_test_under = train_test_split(X_under, y_under, test_size=0.3,random_state=5, stratify=y_under)

# %%
lr_under = LogisticRegression()
lr_under.fit(X_train_under,y_train_under)
# Out:
# LogisticRegression()

# %%
y_predict_lr_under=lr_under.predict(X_test_under)

# %%
print("Accuracy:",accuracy_score(y_test_under, y_predict_lr_under))
print("Precision:",precision_score(y_test_under, y_predict_lr_under))
print("Recall:",recall_score(y_test_under, y_predict_lr_under))
print("f1:",f1_score(y_test_under, y_predict_lr_under))
print("ROC AUC Score:",roc_auc_score(y_test_under, y_predict_lr_under))
fpr, tpr, thresholds =roc_curve(y_test_under, y_predict_lr_under)
roc_auc = auc(fpr, tpr)
print(fpr)
print(tpr)
print(thresholds)
# Out:
# Accuracy: 0.9507042253521126
# Precision: 0.9848484848484849
# Recall: 0.9154929577464789
# f1: 0.948905109489051
# ROC AUC Score: 0.9507042253521127
# [0.         0.01408451 1.        ]
# [0.         0.91549296 1.        ]
# [2 1 0]

# %%
cm=confusion_matrix(y_test_under, y_predict_lr_under)
sns.heatmap(cm, annot=True,fmt = ".1f",
                    cmap=plt.cm.Reds,
                   xticklabels=['No Fraud', 'Fraud'],
                   yticklabels=['No Fraud', 'Fraud']).set_title('Logistic Regression with undersampling')
# Out:
# Text(0.5, 1.0, 'Logistic Regression with undersampling')

# %%
print(classification_report(y_test_under, y_predict_lr_under))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       142
#            1       0.98      0.92      0.95       142
#
#     accuracy                           0.95       284
#    macro avg       0.95      0.95      0.95       284
# weighted avg       0.95      0.95      0.95       284

# %%
pickle.dump(lr_under, open('../models/lr_under.pkl', 'wb'))

# %%
oversample = RandomOverSampler()
X_over, y_over = oversample.fit_resample(X, y)

# %%
X_train_over, X_test_over, y_train_over, y_test_over = train_test_split(X_over, y_over, test_size=0.3,random_state=5, stratify=y_over)

# %%
lr_over = LogisticRegression()
lr_over.fit(X_train_over,y_train_over)
# Out:
# LogisticRegression()

# %%
y_predict_lr_over=lr_over.predict(X_test_over)

# %%
print("Accuracy:",accuracy_score(y_test_over, y_predict_lr_over))
print("Precision:",precision_score(y_test_over, y_predict_lr_over))
print("Recall:",recall_score(y_test_over, y_predict_lr_over))
print("f1:",f1_score(y_test_over, y_predict_lr_over))
print("ROC AUC Score:",roc_auc_score(y_test_over, y_predict_lr_over))
fpr, tpr, thresholds =roc_curve(y_test_over, y_predict_lr_over)
roc_auc = auc(fpr, tpr)
print(fpr)
print(tpr)
print(thresholds)
# Out:
# Accuracy: 0.9483618904161175
# Precision: 0.9753349801631859
# Recall: 0.9199891734136697
# f1: 0.9468539938230485
# ROC AUC Score: 0.9483618904161174
# [0.         0.02326539 1.        ]
# [0.         0.91998917 1.        ]
# [2 1 0]

# %%
cm=confusion_matrix(y_test_over, y_predict_lr_over)
sns.heatmap(cm, annot=True,fmt = ".1f",
                    cmap=plt.cm.Reds,
                   xticklabels=['No Fraud', 'Fraud'],
                   yticklabels=['No Fraud', 'Fraud']).set_title('Logistic Regression with oversampling')
# Out:
# Text(0.5, 1.0, 'Logistic Regression with oversampling')

# %%
pickle.dump(lr_under, open('../models/lr_over.pkl', 'wb'))

# %%
smote_oversample = SMOTE()

# %%
X_smote, y_smote = smote_oversample.fit_resample(X, y)

# %%
X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote, y_smote, test_size=0.3,random_state=5, stratify=y_smote)

# %%
lr_smote = LogisticRegression()
lr_smote.fit(X_train_smote,y_train_smote)
# Out:
# LogisticRegression()

# %%
y_predict_lr_smote=lr_smote.predict(X_test_smote)

# %%
print("Accuracy:",accuracy_score(y_test_smote, y_predict_lr_smote))
print("Precision:",precision_score(y_test_smote, y_predict_lr_smote))
print("Recall:",recall_score(y_test_smote, y_predict_lr_smote))
print("f1:",f1_score(y_test_smote, y_predict_lr_smote))
print("ROC AUC Score:",roc_auc_score(y_test_smote, y_predict_lr_smote))
fpr, tpr, thresholds =roc_curve(y_test_smote, y_predict_lr_smote)
roc_auc = auc(fpr, tpr)
print(fpr)
print(tpr)
print(thresholds)
# Out:
# Accuracy: 0.9456140557333835
# Precision: 0.9727934474535216
# Recall: 0.9168706458294107
# f1: 0.9440045557258567
# ROC AUC Score: 0.9456140557333836
# [0.         0.02564253 1.        ]
# [0.         0.91687065 1.        ]
# [2 1 0]

# %%
cm=confusion_matrix(y_test_smote, y_predict_lr_smote)
sns.heatmap(cm, annot=True,fmt = ".1f",
                    cmap=plt.cm.Reds,
                   xticklabels=['No Fraud', 'Fraud'],
                   yticklabels=['No Fraud', 'Fraud']).set_title('Logistic Regression with smote')
# Out:
# Text(0.5, 1.0, 'Logistic Regression with smote')

# %%
pickle.dump(lr_smote, open('../models/lr_smote.pkl', 'wb'))

# %% [markdown]
# ##### 2. Algorithms wtih class-weights

# %%
lr_cw = LogisticRegression(class_weight='balanced')
lr_cw.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_predict_lr_cw=lr_cw.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_predict_lr_cw))
print("Precision:",precision_score(y_test, y_predict_lr_cw))
print("Recall:",recall_score(y_test, y_predict_lr_cw))
print("f1:",f1_score(y_test, y_predict_lr_cw))
print("ROC AUC Score:",roc_auc_score(y_test, y_predict_lr_cw))
fpr, tpr, thresholds =roc_curve(y_test, y_predict_lr_cw)
roc_auc = auc(fpr, tpr)
print(fpr)
print(tpr)
print(thresholds)
# Out:
# Accuracy: 0.9757395615498484
# Precision: 0.058742542450665444
# Recall: 0.9014084507042254
# f1: 0.1102972856527359
# ROC AUC Score: 0.938636112002461
# [0.         0.02413623 1.        ]
# [0.         0.90140845 1.        ]
# [2 1 0]

# %%
cm=confusion_matrix(y_test, y_predict_lr_cw)
sns.heatmap(cm, annot=True,fmt = ".1f",
                    cmap=plt.cm.Reds,
                   xticklabels=['No Fraud', 'Fraud'],
                   yticklabels=['No Fraud', 'Fraud']).set_title('Logistic Regression with classweights ')
# Out:
# Text(0.5, 1.0, 'Logistic Regression with classweights ')

# %%
pickle.dump(lr_cw, open('../models/lr_cw.pkl', 'wb'))

# %% [markdown]
# ##### 3. Ensemble algorithms

# %% [markdown]
# Basic XGB classifier

# %%
xgb=XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_predict_xgb=xgb.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_predict_xgb))
print("Precision:",precision_score(y_test, y_predict_xgb))
print("Recall:",recall_score(y_test, y_predict_xgb))
print("f1:",f1_score(y_test, y_predict_xgb))
print("ROC AUC Score:",roc_auc_score(y_test, y_predict_xgb))
# Out:
# Accuracy: 0.999530064146244
# Precision: 0.9322033898305084
# Recall: 0.7746478873239436
# f1: 0.846153846153846
# ROC AUC Score: 0.8872768715474924

# %%
cm=confusion_matrix(y_test, y_predict_xgb)
sns.heatmap(cm, annot=True,fmt = ".1f",
                    cmap=plt.cm.Reds,
                   xticklabels=['No Fraud', 'Fraud'],
                   yticklabels=['No Fraud', 'Fraud']).set_title('XGB Classifier')
# Out:
# Text(0.5, 1.0, 'XGB Classifier')

# %%
pickle.dump(xgb, open('../models/xgb_basic.pkl', 'wb'))

# %% [markdown]
# XGBoost with tuning scale-pos-weight for imbalance to match the classweights.
# scale_pos_weight is number of samples in majority class/number of samples in minority class

# %%
y_train.value_counts()
# Out:
# 0    198277
# 1       331
# Name: Class, dtype: int64

# %%
weights = [1, 25, 50, 100, 200, 300, 400, 500]
param_grid = dict(scale_pos_weight=weights)
grid_search = GridSearchCV(xgb, param_grid, scoring="f1_macro", n_jobs=-1, cv=5)


grid_result = grid_search.fit(X_train, y_train)

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.935814 using {'scale_pos_weight': 100}

# %%
xgb_pos=XGBClassifier(scale_pos_weight=100)
xgb_pos.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_predict_xgb_pos=xgb_pos.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_predict_xgb_pos))
print("Precision:",precision_score(y_test, y_predict_xgb_pos))
print("Recall:",recall_score(y_test, y_predict_xgb_pos))
print("f1:",f1_score(y_test, y_predict_xgb_pos))
print("ROC AUC Score:",roc_auc_score(y_test, y_predict_xgb_pos))
# Out:
# Accuracy: 0.9994478253718367
# Precision: 0.8682170542635659
# Recall: 0.7887323943661971
# f1: 0.8265682656826567
# ROC AUC Score: 0.8942661689398298

# %%
cm=confusion_matrix(y_test, y_predict_xgb_pos)
sns.heatmap(cm, annot=True,fmt = ".1f",
                    cmap=plt.cm.Reds,
                   xticklabels=['No Fraud', 'Fraud'],
                   yticklabels=['No Fraud', 'Fraud']).set_title('XGB Classifier with weight balance')
# Out:
# Text(0.5, 1.0, 'XGB Classifier with weight balance')

# %%
pickle.dump(xgb_pos, open('../models/xgb_pos.pkl', 'wb'))

# %% [markdown]
# Basic Random forest classifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict_rf=rf.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_predict_rf))
print("Precision:",precision_score(y_test, y_predict_rf))
print("Recall:",recall_score(y_test, y_predict_rf))
print("f1:",f1_score(y_test, y_predict_rf))
print("ROC AUC Score:",roc_auc_score(y_test, y_predict_rf))
# Out:
# Accuracy: 0.9995065673535563
# Precision: 0.9310344827586207
# Recall: 0.7605633802816901
# f1: 0.8372093023255814
# ROC AUC Score: 0.8802346180263656

# %%
cm=confusion_matrix(y_test, y_predict_rf)
sns.heatmap(cm, annot=True,fmt = ".1f",
                    cmap=plt.cm.Reds,
                   xticklabels=['No Fraud', 'Fraud'],
                   yticklabels=['No Fraud', 'Fraud']).set_title('RF Classifier')
# Out:
# Text(0.5, 1.0, 'RF Classifier')

# %%
pickle.dump(rf, open('../models/rf_basic.pkl', 'wb'))

# %% [markdown]
# Random forest classifier with class weights

# %%
rf_cw= RandomForestClassifier(class_weight='balanced')
rf_cw.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_predict_rf_cw=rf_cw.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, y_predict_rf_cw))
print("Precision:",precision_score(y_test, y_predict_rf_cw))
print("Recall:",recall_score(y_test, y_predict_rf_cw))
print("f1:",f1_score(y_test, y_predict_rf_cw))
print("ROC AUC Score:",roc_auc_score(y_test, y_predict_rf_cw))
# Out:
# Accuracy: 0.9994713221645245
# Precision: 0.9292035398230089
# Recall: 0.7394366197183099
# f1: 0.8235294117647058
# ROC AUC Score: 0.8696712377446756

# %%
cm=confusion_matrix(y_test, y_predict_rf_cw)
sns.heatmap(cm, annot=True,fmt = ".1f",
                    cmap=plt.cm.Reds,
                   xticklabels=['No Fraud', 'Fraud'],
                   yticklabels=['No Fraud', 'Fraud']).set_title('RF Classifier with class weights')
# Out:
# Text(0.5, 1.0, 'RF Classifier with class weights')

# %%
pickle.dump(rf_cw, open('../models/rf_cw.pkl', 'wb'))

# %% [markdown]
# Because of the highly imbalanced dataset in which 0.17% if the data is fraud transaction and 99.83% is not fraud, there is a need to have precision and recall tradeoff for the models. From all the models, the under sampled logistic regression gave good precision and recall.
